# %%
import numpy as np
import tensorflow as tf

# %%
coeffient = np.array([[1.],[-20.],[100.]])
w = tf.Variable(0,dtype=tf.float32)
x = tf.placeholder(tf.float32,[3,1])
# cost = w**2 - 10 * w +25
cost = x[0][0]*w**2 + x[1][0] * w + x[2][0] 
train = tf.train.GradientDescentOptimizer(0.01).minimize(cost)
init = tf.global_variables_initializer()
sess = tf.Session()
sess.run(init)
print(sess.run(w))
# Out:
# 0.0

# %%
sess.run(train,feed_dict={x:coeffient})
sess.run(w)
# Out:
# 0.19999999

# %%
for _ in range(1000):
    sess.run(train,feed_dict={x:coeffient})
sess.run(w)
# Out:
# 9.9999771
